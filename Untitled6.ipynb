# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/auto_mpg.csv',usecols=[0,3])

# %%
df
# Out:
#       mpg  horsepower
# 0    18.0       130.0
# 1    15.0       165.0
# 2    18.0       150.0
# 3    16.0       150.0
# 4    17.0       140.0
# ..    ...         ...
# 393  27.0        86.0
# 394  44.0        52.0
# 395  32.0        84.0
# 396  28.0        79.0
# 397  31.0        82.0
#
# [398 rows x 2 columns]

# %%
sns.scatterplot(data=df, x='mpg',y='horsepower')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scalar= MinMaxScaler()
#fit the scalar to the data set, it will learn the parameters
scalar.fit(df)
#transform data set
df_scaled = scalar.transform(df)
df_scaled
# Out:
# array([[0.2393617 , 0.45652174],
#        [0.15957447, 0.64673913],
#        [0.2393617 , 0.56521739],
#        [0.18617021, 0.56521739],
#        [0.21276596, 0.51086957],
#        [0.15957447, 0.82608696],
#        [0.13297872, 0.94565217],
#        [0.13297872, 0.91847826],
#        [0.13297872, 0.97282609],
#        [0.15957447, 0.7826087 ],
#        [0.15957447, 0.67391304],
#        [0.13297872, 0.61956522],
#        [0.15957447, 0.56521739],
#        [0.13297872, 0.97282609],
#        [0.39893617, 0.26630435],
#        [0.34574468, 0.26630435],
#        [0.2393617 , 0.27717391],
#        [0.31914894, 0.21195652],
#        [0.4787234 , 0.22826087],
#        [0.45212766, 0.        ],
#        [0.42553191, 0.22282609],
#        [0.39893617, 0.23913043],
#        [0.42553191, 0.26630435],
#        [0.45212766, 0.36413043],
#        [0.31914894, 0.23913043],
#        [0.02659574, 0.91847826],
#        [0.02659574, 0.83695652],
#        [0.05319149, 0.89130435],
# ...

# %%
df_scaled
# Out:
# array([[0.2393617 , 0.45652174],
#        [0.15957447, 0.64673913],
#        [0.2393617 , 0.56521739],
#        [0.18617021, 0.56521739],
#        [0.21276596, 0.51086957],
#        [0.15957447, 0.82608696],
#        [0.13297872, 0.94565217],
#        [0.13297872, 0.91847826],
#        [0.13297872, 0.97282609],
#        [0.15957447, 0.7826087 ],
#        [0.15957447, 0.67391304],
#        [0.13297872, 0.61956522],
#        [0.15957447, 0.56521739],
#        [0.13297872, 0.97282609],
#        [0.39893617, 0.26630435],
#        [0.34574468, 0.26630435],
#        [0.2393617 , 0.27717391],
#        [0.31914894, 0.21195652],
#        [0.4787234 , 0.22826087],
#        [0.45212766, 0.        ],
#        [0.42553191, 0.22282609],
#        [0.39893617, 0.23913043],
#        [0.42553191, 0.26630435],
#        [0.45212766, 0.36413043],
#        [0.31914894, 0.23913043],
#        [0.02659574, 0.91847826],
#        [0.02659574, 0.83695652],
#        [0.05319149, 0.89130435],
# ...

# %%
df_scaled = pd.DataFrame(df_scaled, colu)
