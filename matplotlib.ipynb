# %%
import matplotlib.pyplot as plt

# %%
#importing the required packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#importing the required packages
import matplotlib.pyplot as plt
import numpy as np
#creating two arrays
X=np.array([1,2,3,4,5])
Y=X**2
#plotting the values 
plt.plot(X,Y)

# %%
#Object Oriented Interface in Matplotlib:
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values

# %%
#creating an empty canvas/figure
fig = plt.figure()
#creating an empty canvas/figure
fig = plt.figure()
#setting axes as [left, bottom, width, height]
ax = fig.add_axes([0,0,1,1])

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g",label='line1' )

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g",label='line1' )
ax.plot(x,z,color="r",label='line2')

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')
ax.set_title('Title of the Plot',fontsize=15)    
ax.set_xlabel('Label for X axis',fontsize=15)    
ax.set_ylabel('Label for Y axis',fontsize=15)
# Out:
# Text(0, 0.5, 'Label for Y axis')

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')
ax.set_title('Title of the Plot',fontsize=15)   
ax.set_xlabel('Label for X axis',fontsize=15)    
ax.set_ylabel('Label for Y axis',fontsize=15)    
ax.legend()    #adding legend

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
#creating an empty canvas/figure
fig = plt.figure(figsize=(8,5))
#setting axes as [left, bottom, width, height]
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.10,0.42,0.45,0.45])
#plotting the lines
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15) 
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)    
ax1.legend()    #adding legend
ax2.legend()

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
#initializing two axes for the subplot
fig, (ax1, ax2) = plt.subplots(1, 2)    
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15) 

ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)
# Out:
# Text(0, 0.5, 'Plot 2 - Y axis')

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
fig=plt.figure(figsize=(8,8))
#initializing two axes for the subplot

ax1 = fig.add_axes([0,0,0.5,0.5])
ax2 = fig.add_axes([0.6,0,0.5,0.5])
ax3 = fig.add_axes([0,0.6,0.5,0.5])
ax4 = fig.add_axes([0.6,0.6,0.5,0.5])
    
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15) 

ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15) 

ax3.plot(x,z,color="b", label='line3')
ax3.set_title('Title for Plot 3',fontsize=15)    
ax3.set_xlabel('Plot 3 - X axis',fontsize=15)    
ax3.set_ylabel('Plot 3 - Y axis',fontsize=15)    

ax4.plot(x,z,color="y", label='line4')
ax4.set_title('Title for Plot 4',fontsize=15)    
ax4.set_xlabel('Plot 4 - X axis',fontsize=15)    
ax4.set_ylabel('Plot 4 - Y axis',fontsize=15)
# Out:
# Text(0, 0.5, 'Plot 4 - Y axis')

# %%
#importing the data
import pandas as pd
df = pd.read_csv('dataset/auto_mpg.csv')
df #to know the column names,missing values and ther data type
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[6,6])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of mileage')
#plotting boxplot
ax.boxplot(df['mpg'])
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\3533410036.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#processing data for city mileage
df['city_mileage']=df['mpg']*0.75
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  city_mileage
# 0          70    usa  chevrolet chevelle malibu         13.50
# 1          70    usa          buick skylark 320         11.25
# 2          70    usa         plymouth satellite         13.50
# 3          70    usa              amc rebel sst         12.00
# 4          70    usa                ford torino         12.75

# %%
#Comparing avarage mpg and city mpg using boxplot
mpg_list = [df['mpg'],df['city_mileage']]
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[6,6])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of Average MPG vs City MPG')
ax.set_ylabel('Mileage per gallon')
#plotting box plot
ax.boxplot(mpg_list,widths = 0.5)
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\2356910400.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#Types of plots:
#importing the data
import as pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#   Cell In[53], line 3
#     import as pandas as pd
#            ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
#  9   city_milege   398 non-null    float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 31.2+ KB

# %%
#The engineers at XYZ Custom want to infer the correlation between horsepower
#visualizing correlation between mileage and horsepower
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[10,5])
ax = fig.add_axes([0, 0, 1, 1])
ax.scatter(df['horsepower'],df['mpg'])
ax.set_title("Scatter plot of horsepower and mileage",fontsize=16)
ax.set_ylabel('Mileage per gallon',fontsize=12)
ax.set_xlabel('Horsepower',fontsize=12)
# Out:
# Text(0.5, 0, 'Horsepower')

# %%
new=df['origin'].unique()
new
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
import matplotlib.pyplot as plot
import seaborn as sns
import numpy as np

sns.scatterplot(x='horsepower',y='mpg',hue='origin',style='cylinders',data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
df.groupby('model_year').count()['name']
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: name, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2     NaN          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                name
# 0            70       1                 NaN
# 1            70       1   buick skylark 320
# 2            70       1  plymouth satellite
# 3            70       1       amc rebel sst
# 4            70       1         ford torino
# ..          ...     ...                 ...
# 393          82       1     ford mustang gl
# 394          82       2           vw pickup
# 395          82       1       dodge rampage
# 396          82       1         ford ranger
# 397          82       1          chevy s-10
#
# [398 rows x 9 columns]

# %%
nwe_df=df.groupby('model_year').count()[['name']]
nwe_df
# Out:
#             name
# model_year
# 70            28
# 71            28
# 72            28
# 73            40
# 74            27
# 75            30
# 76            34
# 77            28
# 78            36
# 79            29
# 80            29
# 81            29
# 82            31

# %%
df.groupby('model_year').count()[['name']].plot(kind='bar')
# Out:
# <Axes: xlabel='model_year'>

# %%
new_df=df.groupby('model_year').count()[['name']]
nwe_df.reset_index(inplace=True)
nwe_df
# Out:
#     model_year  name
# 0           70    28
# 1           71    28
# 2           72    28
# 3           73    40
# 4           74    27
# 5           75    30
# 6           76    34
# 7           77    28
# 8           78    36
# 9           79    29
# 10          80    29
# 11          81    29
# 12          82    31

# %%
import matplotlib.pyplot as plt
new_df=df.groupby('model_year').count()[['name']]
new_df.reset_index(inplace=True)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title("Number of cars in each year")
ax.set_ylabel('number of cars')
ax.set_xlabel('model_year')
ax.bar(new_df['model_year'],new_df['name'])
# Out:
# <BarContainer object of 13 artists>

# %%
#creating a histogram for horsepower
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,6])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting histogram
ax.hist(df['horsepower'], bins=20)
ax.set_title('Distribution of Horsepower',fontsize = 17)
ax.set_ylabel('Frequency',fontsize=12)
ax.set_xlabel('Horsepower',fontsize=12)
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\4022939591.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
new_df=df.groupby('origin').count()[['name']]
new_df.reset_index(inplace=True)
colors=['blue','yellow','pink']
explode=[0.05,0,0]
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.pie(new_df['name'],labels=new_df['origin'],colors=colors,explode=explode,autopct='%0.1f%%',shadow = True, startangle = 250)
# Out:
# ([<matplotlib.patches.Wedge at 0x202be40bbd0>,
#   <matplotlib.patches.Wedge at 0x202c1301710>,
#   <matplotlib.patches.Wedge at 0x202c1303310>],
#  [Text(0.23238560197888303, -1.1262756909357994, 'europe'),
#   Text(1.0799552533913195, -0.2090374384470184, 'japan'),
#   Text(-0.8095369830840439, 0.7447481943712148, 'usa')],
#  [Text(0.13134838372719473, -0.6365906079202344, '17.6%'),
#   Text(0.5890665018498106, -0.11402042097110092, '19.8%'),
#   Text(-0.4415656271367511, 0.40622628783884435, '62.6%')])

# %%
df['horsepower'].fillna(df['horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
#  9   city_mileage  398 non-null    float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 31.2+ KB

# %%
df['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
df['mpg'].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
df[df['mpg'] == 9]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28  9.0          8         304.0       193.0    4732          18.5
#
#     model_year origin      name  city_mileage
# 28          70    usa  hi 1200d          6.75

# %%
df['city_mileage']=df['mpg']-df['mpg']*0.25
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  city_mileage
# 0            70     usa  chevrolet chevelle malibu         13.50
# 1            70     usa          buick skylark 320         11.25
# 2            70     usa         plymouth satellite         13.50
# 3            70     usa              amc rebel sst         12.00
# 4            70     usa                ford torino         12.75
# ..          ...     ...                        ...           ...
# 393          82     usa            ford mustang gl         20.25
# 394          82  europe                  vw pickup         33.00
# 395          82     usa              dodge rampage         24.00
# 396          82     usa                ford ranger         21.00
# 397          82     usa                 chevy s-10         23.25
#
# [398 rows x 10 columns]

# %%
q1 = df['mpg'].quantile(0.25)
q1
# Out:
# 17.5

# %%
q3 = df['mpg'].quantile(0.75)
q3
# Out:
# 29.0

# %%
iqr = q3 -q1
iqr
# Out:
# 11.5

# %%
df['mpg'][28] < q1 - iqr*(1.5)
# Out:
# False

# %%
df['mpg'][28] < q3 - iqr*(1.5)
# Out:
# True

# %%
#LINE CHART:
#Problem Statement:
#XYZ Custom Cars is planning to generate a report comparing the Mileage, Horsepower, and Weight of the cars manufactured in different years, starting from 1970 to 1982.
line_df=df.groupby(by=['model_year'])
line_df=line_df.mean()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\728663299.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   line_df=line_df.mean()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage /10')
ax.plot(line_df['weight']/1000,label='Weight /1000')
ax.plot(line_df['horsepower']/100,label='Horsepower /100')
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\3765946225.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage', linestyle='-',linewidth=2)
ax.plot(line_df['weight']/1000,label='Weight',linestyle=':',linewidth=3)
ax.plot(line_df['horsepower']/100,label='Horsepower',linestyle='--',linewidth=3)
# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\1647559316.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[10,5])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage')
ax.plot(line_df['weight']/1000,label='Weight')
ax.plot(line_df['horsepower']/100,label='Horsepower')
plt.text(75.5, 1.14, 'Horsepower',
             va = 'center', #va -> vertical alignment
             rotation = 4, #angle
             bbox = dict( 
                     boxstyle = 'round',
                     facecolor = 'wheat',
                     alpha = 0.3)) #background style
plt.text(75.5, 2.25, 'Mileage',va = 'center',rotation = 17,bbox = dict(boxstyle = 'round',facecolor = 'wheat',alpha = 0.3))
plt.text(76, 3.15, 'Weight',va = 'center',rotation = -13,bbox = dict(boxstyle = 'round',facecolor = 'wheat',alpha = 0.3))
plt.annotate('Highest Mileage', xy=(80.1, 3.39), xytext=(80.5, 3.38), arrowprops=dict(facecolor='wheat', shrink=.01))
plt.annotate('Lowest Mileage', xy=(73.05, 1.70), xytext=(73.5, 1.69), arrowprops=dict(facecolor='wheat', shrink=.01))
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\4102938735.py:25: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage', color="g", marker='+', markersize = 7)
ax.plot(line_df['weight']/1000,label='Weight', color="b", marker='o', markersize = 7)
ax.plot(line_df['horsepower']/100,label='Horsepower', color="r", marker='s', markersize = 7)
# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\3245933419.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import pandas as pd
df = pd.read_excel('dataset/saledata.xlsx')
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00     500.000
# 12 2018-07-29     East  Douglas      Karen  Home Theater   81.00     500.000
# 13 2018-08-15     East   Martha  Alexander    Television   35.00    1198.000
# 14 2018-09-01  Central  Douglas       John          Desk    2.00     125.000
# 15 2018-09-18     East   Martha  Alexander   Video Games   16.00      58.500
# 16 2018-10-05  Central  Hermann      Sigal  Home Theater   28.00     500.000
# 17 2018-10-22     East   Martha  Alexander    Cell Phone   64.00     225.000
# 18 2018-11-08     East  Douglas      Karen    Cell Phone   15.00     225.000
# 19 2018-11-25  Central  Hermann     Shelli   Video Games   96.00      58.500
# 20 2018-12-12  Central  Douglas       John    Television   67.00    1198.000
# 21 2018-12-29     East  Douglas      Karen   Video Games   74.00      58.500
# 22 2019-01-15  Central  Timothy      David  Home Theater   46.00     500.000
# 23 2019-02-01  Central  Douglas       John  Home Theater   87.00     500.000
# 24 2019-02-18     East   Martha  Alexander  Home Theater    4.00     500.000
# 25 2019-03-07     West  Timothy    Stephen  Home Theater    7.00     500.000
# 26 2019-03-24  Central  Hermann       Luis   Video Games   50.00      58.500
# 27 2019-04-10  Central   Martha     Steven    Television   66.00    1198.000
# 28 2019-04-27     East   Martha      Diana    Cell Phone   96.00     225.000
# 29 2019-05-14  Central  Timothy      David    Television   53.00    1198.000
# 30 2019-05-31  Central  Timothy      David  Home Theater   80.00     500.000
# 31 2019-06-17  Central  Hermann     Shelli          Desk    5.00     125.000
# 32 2019-07-04     East   Martha  Alexander   Video Games   62.00      58.500
# 33 2019-07-21  Central  Hermann      Sigal   Video Games   55.00      58.500
# 34 2019-08-07  Central  Hermann     Shelli   Video Games   42.00      58.500
# 35 2019-08-24     West  Timothy    Stephen          Desk    3.00     125.000
# 36 2019-09-10  Central  Timothy      David    Television    7.00    1198.000
# 37 2019-09-27     West  Timothy    Stephen    Cell Phone   76.00     225.000
# 38 2019-10-14     West  Douglas    Michael  Home Theater   57.00     500.000
# 39 2019-10-31  Central   Martha     Steven    Television   14.00    1198.000
# 40 2019-11-17  Central  Hermann       Luis  Home Theater   11.00     500.000
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 43        NaT      NaN      NaN        NaN           NaN  278.00    1125.000
# 44        NaT      NaN      NaN        NaN           NaN   34.75     140.625
#
#      Sale_amt
# 0   113810.00
# 1    25000.00
# 2    43128.00
# 3     6075.00
# 4    67088.00
# 5    30000.00
# 6    89850.00
# 7   107820.00
# 8    38336.00
# 9    30000.00
# 10  107820.00
# 11   14500.00
# 12   40500.00
# 13   41930.00
# 14     250.00
# 15     936.00
# 16   14000.00
# 17   14400.00
# 18    3375.00
# 19    5616.00
# 20   80266.00
# 21    4329.00
# 22   23000.00
# 23   43500.00
# 24    2000.00
# 25    3500.00
# 26    2925.00
# 27   79068.00
# 28   21600.00
# 29   63494.00
# 30   40000.00
# 31     625.00
# 32    3627.00
# 33    3217.50
# 34    2457.00
# 35     375.00
# 36    8386.00
# 37   17100.00
# 38   28500.00
# 39   16772.00
# 40    5500.00
# 41   47000.00
# 42   14000.00
# 43   62550.00
# 44    7818.75

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       45 non-null     float64
#  6   Unit_price  45 non-null     float64
#  7   Sale_amt    45 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ KB

# %%
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6  2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television   32.0      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.0      1198.0
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.0       500.0
# 12 2018-07-29     East  Douglas      Karen  Home Theater   81.0       500.0
# 13 2018-08-15     East   Martha  Alexander    Television   35.0      1198.0
# 14 2018-09-01  Central  Douglas       John          Desk    2.0       125.0
# 15 2018-09-18     East   Martha  Alexander   Video Games   16.0        58.5
# 16 2018-10-05  Central  Hermann      Sigal  Home Theater   28.0       500.0
# 17 2018-10-22     East   Martha  Alexander    Cell Phone   64.0       225.0
# 18 2018-11-08     East  Douglas      Karen    Cell Phone   15.0       225.0
# 19 2018-11-25  Central  Hermann     Shelli   Video Games   96.0        58.5
# 20 2018-12-12  Central  Douglas       John    Television   67.0      1198.0
# 21 2018-12-29     East  Douglas      Karen   Video Games   74.0        58.5
# 22 2019-01-15  Central  Timothy      David  Home Theater   46.0       500.0
# 23 2019-02-01  Central  Douglas       John  Home Theater   87.0       500.0
# 24 2019-02-18     East   Martha  Alexander  Home Theater    4.0       500.0
# 25 2019-03-07     West  Timothy    Stephen  Home Theater    7.0       500.0
# 26 2019-03-24  Central  Hermann       Luis   Video Games   50.0        58.5
# 27 2019-04-10  Central   Martha     Steven    Television   66.0      1198.0
# 28 2019-04-27     East   Martha      Diana    Cell Phone   96.0       225.0
# 29 2019-05-14  Central  Timothy      David    Television   53.0      1198.0
# 30 2019-05-31  Central  Timothy      David  Home Theater   80.0       500.0
# 31 2019-06-17  Central  Hermann     Shelli          Desk    5.0       125.0
# 32 2019-07-04     East   Martha  Alexander   Video Games   62.0        58.5
# 33 2019-07-21  Central  Hermann      Sigal   Video Games   55.0        58.5
# 34 2019-08-07  Central  Hermann     Shelli   Video Games   42.0        58.5
# 35 2019-08-24     West  Timothy    Stephen          Desk    3.0       125.0
# 36 2019-09-10  Central  Timothy      David    Television    7.0      1198.0
# 37 2019-09-27     West  Timothy    Stephen    Cell Phone   76.0       225.0
# 38 2019-10-14     West  Douglas    Michael  Home Theater   57.0       500.0
# 39 2019-10-31  Central   Martha     Steven    Television   14.0      1198.0
# 40 2019-11-17  Central  Hermann       Luis  Home Theater   11.0       500.0
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.0       500.0
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.0       500.0
#
#     Sale_amt
# 0   113810.0
# 1    25000.0
# 2    43128.0
# 3     6075.0
# 4    67088.0
# 5    30000.0
# 6    89850.0
# 7   107820.0
# 8    38336.0
# 9    30000.0
# 10  107820.0
# 11   14500.0
# 12   40500.0
# 13   41930.0
# 14     250.0
# 15     936.0
# 16   14000.0
# 17   14400.0
# 18    3375.0
# 19    5616.0
# 20   80266.0
# 21    4329.0
# 22   23000.0
# 23   43500.0
# 24    2000.0
# 25    3500.0
# 26    2925.0
# 27   79068.0
# 28   21600.0
# 29   63494.0
# 30   40000.0
# 31     625.0
# 32    3627.0
# 33    3217.5
# 34    2457.0
# 35     375.0
# 36    8386.0
# 37   17100.0
# 38   28500.0
# 39   16772.0
# 40    5500.0
# 41   47000.0
# 42   14000.0

# %%
#1.Using matplotlib bar chart display total amout of sales region wise.
df1 = df.groupby('Region').sum()['Sale_amt']
df1
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\879850069.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby('Region').sum()['Sale_amt']
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64

# %%
df1.index
# Out:
# Index(['Central', 'East', 'West'], dtype='object', name='Region')

# %%
df1
# Out:
# Region
# Central    829769.5
# East       321007.0
# West       154899.0
# Name: Sale_amt, dtype: float64

# %%
ax.plot(df1.index,df1)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
df1 = df.groupby('Region').sum()['Sale_amt']
ax.bar(df1.index,df1)
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\2114609870.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby('Region').sum()['Sale_amt']
# <BarContainer object of 3 artists>

# %%
#1.Using matplotlib bar chart display total amout of sales region wise.
df2 = df.groupby('Item').sum()['Units']
df2
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\1590189483.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby('Item').sum()['Units']
# Item
# Cell Phone      278.0
# Desk             10.0
# Home Theater    722.0
# Television      716.0
# Video Games     395.0
# Name: Units, dtype: float64

# %%
df2.index
# Out:
# Index(['Cell Phone', 'Desk', 'Home Theater', 'Television', 'Video Games'], dtype='object', name='Item')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
df2 = df.groupby('Item').sum()['Units']
ax.bar(df2.index,df2)
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\3313842638.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby('Item').sum()['Units']
# <BarContainer object of 5 artists>

# %%
df3 = df.groupby('Manager').sum()['Sale_amt']
df3
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\4158463407.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby('Manager').sum()['Sale_amt']
# Manager
# Douglas    239056.0
# Hermann    365108.5
# Martha     472493.0
# Timothy    229018.0
# Name: Sale_amt, dtype: float64

# %%
df3.index
# Out:
# Index(['Douglas', 'Hermann', 'Martha', 'Timothy'], dtype='object', name='Manager')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
df3 = df.groupby('Manager').sum()['Sale_amt']
ax.bar(df3.index,df3)
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7336\3115178006.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby('Manager').sum()['Sale_amt']
# <BarContainer object of 4 artists>

# %%
import pandas as pd
df = pd.read_csv('dataset/auto_mpg.csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
#APPENDIX:
# TO save a figure --
import matplotlib.pyplot as plt
import pandas as pd
new_df=df.groupby('origin').count()[['name']]
new_df.reset_index(inplace=True)
colors=['blue','yellow','pink']
explode=[0.05,0,0]
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.pie(new_df['name'],labels=new_df['origin'],colors=colors,explode=explode,autopct='%0.1f%%',shadow = True, startangle = 250)
fig.savefig("pieChart.jpg",dpi = 200)

# %%
#Markers
#importing the required packages
import matplotlib.pyplot as plt
line_df=df.groupby(by=['model_year'])
line_df=line_df.mean()
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage', color="g", marker='+', markersize = 7)
ax.plot(line_df['weight']/1000,label='Weight', color="b", marker='o', markersize = 7)
ax.plot(line_df['horsepower']/100,label='Horsepower', color="r", marker='s', markersize = 7)
# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
#when graph plotted using plt
plt.savefig("lineChart.jpg",dpi = 200)
# Out:
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7580\3631165554.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   line_df=line_df.mean()
# C:\Users\blde2\AppData\Local\Temp\ipykernel_7580\3631165554.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0.0,5.0,0.1)
y = np.cos(2 * np.pi * x) * np.exp(-x)
plt.title('Main Heading')
plt.xlabel('abscissa')
plt.ylabel('ordinate')
plt.annotate('2nd crest', xy=(2,0.2), xytext=((2,0.2)), arrowprops=dict(facecolor='wheat', shrink=.01))
plt.plot(x,y)
plt.show()
